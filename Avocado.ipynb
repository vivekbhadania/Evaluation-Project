# %% [markdown]
# # Avacado Project

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# # Avocado is a fruit consumed by people heavily in the United States.

# %% [markdown]
# # Content

# %% [raw]
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.

# %% [raw]
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.

# %% [raw]
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.

# %% [raw]
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.

# %% [markdown]
# # Inspiration /Label

# %% [raw]
# The dataset can be seen in two angles to find the region and find the average price .

# %% [raw]
# Task: One of Classification and other of Regression

# %% [raw]
# Do both tasks in the same .ipynb file and submit at single file.

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from scipy.stats import zscore

from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression,Lasso,Ridge,LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score,r2_score,mean_tweedie_deviance
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.svm import SVC

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('avocado.csv')
df.head()    #First five rows of data
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %% [markdown]
# Exploratory Data Analysis

# %%
df1=df.iloc[:,1:]     ##Removing unnecessary index column
df1
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1      2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2      2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3      2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4      2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 18244  2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region
# 0                Albany
# 1                Albany
# 2                Albany
# 3                Albany
# 4                Albany
# ...                 ...
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
df1.dtypes    ### To get Data types
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df1.describe(include='all')
# Out:
#               Date  AveragePrice  Total Volume          4046          4225  \
# count        18249  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# unique         169           NaN           NaN           NaN           NaN
# top     2015-12-27           NaN           NaN           NaN           NaN
# freq           108           NaN           NaN           NaN           NaN
# mean           NaN      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std            NaN      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min            NaN      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%            NaN      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%            NaN      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%            NaN      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max            NaN      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                 4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count   1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# unique           NaN           NaN           NaN           NaN            NaN
# top              NaN           NaN           NaN           NaN            NaN
# freq             NaN           NaN           NaN           NaN            NaN
# mean    2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std     1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%     0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%     1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%     6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max     2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                 type          year  region
# count          18249  18249.000000   18249
# unique             2           NaN      54
# top     conventional           NaN  Albany
# freq            9126           NaN     338
# mean             NaN   2016.147899     NaN
# std              NaN      0.939938     NaN
# min              NaN   2015.000000     NaN
# 25%              NaN   2015.000000     NaN
# 50%              NaN   2016.000000     NaN
# 75%              NaN   2017.000000     NaN
# max              NaN   2018.000000     NaN

# %% [markdown]
# # ** The above table shows detailed description of data

# %%
df1['Date']=pd.to_datetime(df1['Date'])
df['Month']=df1['Date'].apply(lambda x:x.month)
df1['Day']=df1['Date'].apply(lambda x:x.day)
df1
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0         8696.87     8603.62       93.25          0.0  conventional  2015
# 1         9505.56     9408.07       97.49          0.0  conventional  2015
# 2         8145.35     8042.21      103.14          0.0  conventional  2015
# 3         5811.16     5677.40      133.76          0.0  conventional  2015
# 4         6183.95     5986.26      197.69          0.0  conventional  2015
# ...           ...         ...         ...          ...           ...   ...
# 18244    13498.67    13066.82      431.85          0.0       organic  2018
# 18245     9264.84     8940.04      324.80          0.0       organic  2018
# 18246     9394.11     9351.80       42.31          0.0       organic  2018
# 18247    10969.54    10919.54       50.00          0.0       organic  2018
# 18248    12014.15    11988.14       26.01          0.0       organic  2018
#
#                  region  Day
# 0                Albany   27
# 1                Albany   20
# 2                Albany   13
# 3                Albany    6
# 4                Albany   29
# ...                 ...  ...
# 18244  WestTexNewMexico    4
# 18245  WestTexNewMexico   28
# 18246  WestTexNewMexico   21
# 18247  WestTexNewMexico   14
# 18248  WestTexNewMexico    7
#
# [18249 rows x 14 columns]

# %%
##Converting Date in the form of Object int DateFrame

# %%
df.shape       ##To get no. of rows and columns
# Out:
# (18249, 15)

# %%
df1.columns    ## To get columns names from the data
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region', 'Day'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
#  13  Day           18249 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %% [raw]
# The above information shows null values,data types and no.of rows

# %% [markdown]
# # Finding null values

# %%
df1.isnull().all()
# Out:
# Date            False
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type            False
# year            False
# region          False
# Day             False
# dtype: bool

# %%
sns.heatmap(df1.isnull())
plt.show()

# %% [markdown]
# Hence there is no null values in the data

# %% [markdown]
# # Data Visualization

# %%
print(df1['region'].nunique())
print(df1['region'].value_counts())
plt.figure(figsize=(20,10))
sns.countplot(df1.region)
plt.xticks(rotation=45)
plt.show()
# Out:
# 54
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %%
print(df['type'].unique())
print(df1['type'].value_counts())
sns.countplot(df1.type)
plt.show
# Out:
# ['conventional' 'organic']
# conventional    9126
# organic         9123
# Name: type, dtype: int64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(df1.year.unique())
sns.countplot(df1.year)
plt.show()
# Out:
# [2015 2016 2017 2018]

# %%
df1['AveragePrice'].plot()
# Out:
# <AxesSubplot:>

# %%
##checking organic

df1.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.375590
# 2016    1.338640
# 2017    1.515128
# 2018    1.347531
# Name: AveragePrice, dtype: float64

# %%
#df1.groupby('year')['type'].value_counts()
df1.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %% [markdown]
# # Data Encoding using LabelEncoder

# %%
le=LabelEncoder()
varib=['Date','type','region']
for i in varib:
    df1[i]=le.fit_transform(df1[i])
df1
# Out:
#        Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0        51          1.33      64236.62  1036.74   54454.85   48.16
# 1        50          1.35      54876.98   674.28   44638.81   58.33
# 2        49          0.93     118220.22   794.70  109149.67  130.50
# 3        48          1.08      78992.15  1132.00   71976.41   72.58
# 4        47          1.28      51039.60   941.48   43838.39   75.78
# ...     ...           ...           ...      ...        ...     ...
# 18244   161          1.63      17074.83  2046.96    1529.20    0.00
# 18245   160          1.71      13888.04  1191.70    3431.50    0.00
# 18246   159          1.87      13766.76  1191.92    2452.79  727.94
# 18247   158          1.93      16205.22  1527.63    2981.04  727.01
# 18248   157          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  \
# 0         8696.87     8603.62       93.25          0.0     0  2015       0
# 1         9505.56     9408.07       97.49          0.0     0  2015       0
# 2         8145.35     8042.21      103.14          0.0     0  2015       0
# 3         5811.16     5677.40      133.76          0.0     0  2015       0
# 4         6183.95     5986.26      197.69          0.0     0  2015       0
# ...           ...         ...         ...          ...   ...   ...     ...
# 18244    13498.67    13066.82      431.85          0.0     1  2018      53
# 18245     9264.84     8940.04      324.80          0.0     1  2018      53
# 18246     9394.11     9351.80       42.31          0.0     1  2018      53
# 18247    10969.54    10919.54       50.00          0.0     1  2018      53
# 18248    12014.15    11988.14       26.01          0.0     1  2018      53
#
#        Day
# 0       27
# 1       20
# 2       13
# 3        6
# 4       29
# ...    ...
# 18244    4
# 18245   28
# 18246   21
# 18247   14
# 18248    7
#
# [18249 rows x 14 columns]

# %%
df1.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>],
#        [<AxesSubplot:title={'center':'4225'}>,
#         <AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>],
#        [<AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>,
#         <AxesSubplot:title={'center':'type'}>,
#         <AxesSubplot:title={'center':'year'}>],
#        [<AxesSubplot:title={'center':'region'}>,
#         <AxesSubplot:title={'center':'Day'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # Multicollinearity pairplot

# %%
sns.pairplot(df1)

# %% [markdown]
# # Correlation matrix

# %%
df1.corr()
# Out:
#                   Date  AveragePrice  Total Volume      4046      4225  \
# Date          1.000000      0.145514      0.009263 -0.005028 -0.016895
# AveragePrice  0.145514      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume  0.009263     -0.192752      1.000000  0.977863  0.974181
# 4046         -0.005028     -0.208317      0.977863  1.000000  0.926110
# 4225         -0.016895     -0.172928      0.974181  0.926110  1.000000
# 4770         -0.047517     -0.179446      0.872202  0.833389  0.887855
# Total Bags    0.064688     -0.177088      0.963047  0.920057  0.905787
# Small Bags    0.056902     -0.174730      0.967238  0.925280  0.916031
# Large Bags    0.081855     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags   0.077374     -0.117592      0.747157  0.699377  0.688809
# type         -0.000060      0.615845     -0.232434 -0.225819 -0.232289
# year          0.950274      0.093197      0.017193  0.003353 -0.009559
# region       -0.000101     -0.011716      0.174176  0.192073  0.145726
# Day           0.033477      0.027386     -0.009747 -0.010159 -0.012393
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date         -0.047517    0.064688    0.056902    0.081855     0.077374
# AveragePrice -0.179446   -0.177088   -0.174730   -0.172940    -0.117592
# Total Volume  0.872202    0.963047    0.967238    0.880640     0.747157
# 4046          0.833389    0.920057    0.925280    0.838645     0.699377
# 4225          0.887855    0.905787    0.916031    0.810015     0.688809
# 4770          1.000000    0.792314    0.802733    0.698471     0.679861
# Total Bags    0.792314    1.000000    0.994335    0.943009     0.804233
# Small Bags    0.802733    0.994335    1.000000    0.902589     0.806845
# Large Bags    0.698471    0.943009    0.902589    1.000000     0.710858
# XLarge Bags   0.679861    0.804233    0.806845    0.710858     1.000000
# type         -0.210027   -0.217788   -0.220535   -0.193177    -0.175483
# year         -0.036531    0.071552    0.063915    0.087891     0.081033
# region        0.095252    0.175256    0.164702    0.198768     0.082281
# Day          -0.009009   -0.004988   -0.003870   -0.008352     0.000319
#
#                   type      year    region       Day
# Date         -0.000060  0.950274 -0.000101  0.033477
# AveragePrice  0.615845  0.093197 -0.011716  0.027386
# Total Volume -0.232434  0.017193  0.174176 -0.009747
# 4046         -0.225819  0.003353  0.192073 -0.010159
# 4225         -0.232289 -0.009559  0.145726 -0.012393
# 4770         -0.210027 -0.036531  0.095252 -0.009009
# Total Bags   -0.217788  0.071552  0.175256 -0.004988
# Small Bags   -0.220535  0.063915  0.164702 -0.003870
# Large Bags   -0.193177  0.087891  0.198768 -0.008352
# XLarge Bags  -0.175483  0.081033  0.082281  0.000319
# type          1.000000 -0.000032 -0.000280 -0.000013
# year         -0.000032  1.000000 -0.000055  0.004475
# region       -0.000280 -0.000055  1.000000 -0.000021
# Day          -0.000013  0.004475 -0.000021  1.000000

# %%
plt.figure(figsize=(18,12),facecolor='yellow')
sns.heatmap(df1.corr(),cmap='Blues',annot=True)
plt.title("Correlation matrix")
plt.show()

# %% [markdown]
# The above plot shows positive and negetive correlation between feature and labels

# %% [markdown]
# # Distribution plot

# %%
plt.figure(figsize=(16,12))
plotnumber=1

for col in df1:
    if plotnumber<14:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(df1[col])
        plt.xlabel(col,fontsize=12)
        
        plotnumber+=1
        plt.tight_layout

# %%
##Finding skewness

# %%
df1.plot(kind='density',subplots=True,layout=(4,6),sharex=False,legend=True,fontsize=1,figsize=(18,15))
plt.show()

# %% [raw]
# ##Splitting features and labels

# %%
x=df1.drop(['AveragePrice'],axis=1)
y=df1['AveragePrice']

# %%
x.skew().sort_values()
# Out:
# region           0.000030
# Date             0.000117
# type             0.000329
# Day              0.014310
# year             0.215339
# 4046             8.648220
# 4225             8.942466
# Total Volume     9.007687
# Small Bags       9.540660
# Total Bags       9.756072
# Large Bags       9.796455
# 4770            10.159396
# XLarge Bags     13.139751
# dtype: float64

# %% [markdown]
# The above values shows there is lot of right sided skewed data

# %% [markdown]
# # ##Removing Skewness

# %%
x_skew=np.cbrt(x[x.columns])
x_skew.skew()
# Out:
# Date           -0.971817
# Total Volume    2.236143
# 4046            2.277861
# 4225            2.130378
# 4770            2.316048
# Total Bags      2.302176
# Small Bags      2.217682
# Large Bags      2.186514
# XLarge Bags     2.842255
# type            0.000329
# year            0.214909
# region         -1.172781
# Day            -0.698246
# dtype: float64

# %% [markdown]
# # ##Pre-processing Data##

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x_skew)
x_new
# Out:
# array([[-0.58423196, -0.08868514, -0.66707396, ..., -1.21941815,
#         -2.19577142,  1.23131338],
#        [-0.60616857, -0.15815421, -0.78213486, ..., -1.21941815,
#         -2.19577142,  0.53496136],
#        [-0.62822071,  0.17860831, -0.73855207, ..., -1.21941815,
#         -2.19577142, -0.21797925],
#        ...,
#        [ 1.41727754, -0.7753251 , -0.62910639, ...,  1.97154472,
#          1.54465713,  0.637265  ],
#        [ 1.40074201, -0.70194415, -0.56077571, ...,  1.97154472,
#          1.54465713, -0.10562954],
#        [ 1.38418206, -0.66767237, -0.38025601, ...,  1.97154472,
#          1.54465713, -0.94619964]])

# %%
X=pd.DataFrame(x_new,columns=x.columns)
X
# Out:
#            Date  Total Volume      4046      4225      4770  Total Bags  \
# 0     -0.584232     -0.088685 -0.667074  0.306945 -0.178290   -0.528822
# 1     -0.606169     -0.158154 -0.782135  0.230613 -0.141875   -0.490578
# 2     -0.628221      0.178608 -0.738552  0.581288  0.016451   -0.556920
# 3     -0.650392      0.002248 -0.643184  0.415636 -0.099721   -0.700609
# 4     -0.672685     -0.190194 -0.693122  0.223711 -0.091325   -0.674293
# ...         ...           ...       ...       ...       ...         ...
# 18244  1.450276     -0.678453 -0.478926 -0.926164 -1.276496   -0.338490
# 18245  1.433789     -0.771375 -0.629157 -0.672791 -1.276496   -0.501624
# 18246  1.417278     -0.775325 -0.629106 -0.779870  0.378277   -0.495659
# 18247  1.400742     -0.701944 -0.560776 -0.717983  0.377998   -0.428697
# 18248  1.384182     -0.667672 -0.380256 -0.792518  0.127493   -0.389231
#
#        Small Bags  Large Bags  XLarge Bags      type      year    region  \
# 0       -0.348336   -0.725134    -0.708808 -0.999836 -1.219418 -2.195771
# 1       -0.314277   -0.716582    -0.708808 -0.999836 -1.219418 -2.195771
# 2       -0.373885   -0.705678    -0.708808 -0.999836 -1.219418 -2.195771
# 3       -0.503509   -0.654352    -0.708808 -0.999836 -1.219418 -2.195771
# 4       -0.484028   -0.574084    -0.708808 -0.999836 -1.219418 -2.195771
# ...           ...         ...          ...       ...       ...       ...
# 18244   -0.186980   -0.402052    -0.708808  1.000164  1.971545  1.544657
# 18245   -0.333751   -0.466559    -0.708808  1.000164  1.971545  1.544657
# 18246   -0.316571   -0.869126    -0.708808  1.000164  1.971545  1.544657
# 18247   -0.256960   -0.839950    -0.708808  1.000164  1.971545  1.544657
# 18248   -0.220691   -0.950356    -0.708808  1.000164  1.971545  1.544657
#
#             Day
# 0      1.231313
# 1      0.534961
# 2     -0.217979
# 3     -1.081017
# 4      1.422997
# ...         ...
# 18244 -1.371261
# 18245  1.327503
# 18246  0.637265
# 18247 -0.105630
# 18248 -0.946200
#
# [18249 rows x 13 columns]

# %% [markdown]
# # _Distribution plot after removing skewness in the data_

# %%
plt.figure(figsize=(16,12))
plotnumber=1

for col in X:
    if plotnumber<14:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(X[col])
        plt.xlabel(col,fontsize=12)
        
        plotnumber+=1
        plt.tight_layout

# %% [markdown]
# # Scatterplot between features and labels

# %%
plt.figure(figsize=(15,10),facecolor='Yellow')
plotnumber=1

for column in X:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.scatterplot(X[column],y)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('AveragePrice')
    
        plotnumber+=1
        plt.tight_layout

# %% [markdown]
# # ##Finding Outliers

# %%
df1.boxplot(figsize=(20,12))
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
(np.abs(zscore(df1))<3).all()
# Out:
# Date             True
# AveragePrice    False
# Total Volume    False
# 4046            False
# 4225            False
# 4770            False
# Total Bags      False
# Small Bags      False
# Large Bags      False
# XLarge Bags     False
# type             True
# year             True
# region           True
# Day              True
# dtype: bool

# %% [markdown]
# # ##Removing of Outliers

# %%
scores=np.abs(zscore(df1))
t=3
np.where(scores<3)
# Out:
# (array([    0,     0,     0, ..., 18248, 18248, 18248], dtype=int64),
#  array([ 0,  1,  2, ..., 11, 12, 13], dtype=int64))

# %%
df_out=df1[(scores<3).all(axis=1)]
df_out.shape
# Out:
# (17651, 14)

# %%
df1.shape
# Out:
# (18249, 14)

# %%
###reset index

df_out.reset_index()  #reset index
# Out:
#        index  Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0          0    51          1.33      64236.62  1036.74   54454.85   48.16
# 1          1    50          1.35      54876.98   674.28   44638.81   58.33
# 2          2    49          0.93     118220.22   794.70  109149.67  130.50
# 3          3    48          1.08      78992.15  1132.00   71976.41   72.58
# 4          4    47          1.28      51039.60   941.48   43838.39   75.78
# ...      ...   ...           ...           ...      ...        ...     ...
# 17646  18244   161          1.63      17074.83  2046.96    1529.20    0.00
# 17647  18245   160          1.71      13888.04  1191.70    3431.50    0.00
# 17648  18246   159          1.87      13766.76  1191.92    2452.79  727.94
# 17649  18247   158          1.93      16205.22  1527.63    2981.04  727.01
# 17650  18248   157          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  \
# 0         8696.87     8603.62       93.25          0.0     0  2015       0
# 1         9505.56     9408.07       97.49          0.0     0  2015       0
# 2         8145.35     8042.21      103.14          0.0     0  2015       0
# 3         5811.16     5677.40      133.76          0.0     0  2015       0
# 4         6183.95     5986.26      197.69          0.0     0  2015       0
# ...           ...         ...         ...          ...   ...   ...     ...
# 17646    13498.67    13066.82      431.85          0.0     1  2018      53
# 17647     9264.84     8940.04      324.80          0.0     1  2018      53
# 17648     9394.11     9351.80       42.31          0.0     1  2018      53
# 17649    10969.54    10919.54       50.00          0.0     1  2018      53
# 17650    12014.15    11988.14       26.01          0.0     1  2018      53
#
#        Day
# 0       27
# 1       20
# 2       13
# 3        6
# 4       29
# ...    ...
# 17646    4
# 17647   28
# 17648   21
# 17649   14
# 17650    7
#
# [17651 rows x 15 columns]

# %% [markdown]
# # Splitting feautures and labels

# %%
X_new=df_out.drop(['AveragePrice'],axis=1)
Y=df_out['AveragePrice']
features=X_new.columns
features
# Out:
# Index(['Date', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'Day'],
#       dtype='object')

# %% [markdown]
# # Scaling Data

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
x_scaled=pd.DataFrame(std.fit_transform(X_new))
x_scaled
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.664946 -0.392009 -0.349452 -0.278497 -0.322219 -0.429348 -0.400967
# 1     -0.685424 -0.401251 -0.350276 -0.303093 -0.321924 -0.426481 -0.397462
# 2     -0.705902 -0.338702 -0.350002 -0.141449 -0.319832 -0.431303 -0.403413
# 3     -0.726380 -0.377438 -0.349235 -0.234593 -0.321511 -0.439577 -0.413717
# 4     -0.746858 -0.405040 -0.349668 -0.305098 -0.321418 -0.438256 -0.412371
# ...         ...       ...       ...       ...       ...       ...       ...
# 17646  1.587626 -0.438579 -0.347153 -0.411112 -0.323616 -0.412326 -0.381520
# 17647  1.567148 -0.441726 -0.349099 -0.406345 -0.323616 -0.427335 -0.399501
# 17648  1.546670 -0.441846 -0.349098 -0.408798 -0.302508 -0.426876 -0.397707
# 17649  1.526192 -0.439438 -0.348335 -0.407474 -0.302535 -0.421292 -0.390876
# 17650  1.505714 -0.438169 -0.345225 -0.409040 -0.317105 -0.417589 -0.386220
#
#              7         8         9         10        11        12
# 0     -0.379832 -0.259027 -1.019047 -1.210013 -1.695495  1.289309
# 1     -0.379774 -0.259027 -1.019047 -1.210013 -1.695495  0.491652
# 2     -0.379696 -0.259027 -1.019047 -1.210013 -1.695495 -0.306004
# 3     -0.379277 -0.259027 -1.019047 -1.210013 -1.695495 -1.103660
# 4     -0.378402 -0.259027 -1.019047 -1.210013 -1.695495  1.517211
# ...         ...       ...       ...       ...       ...       ...
# 17646 -0.375195 -0.259027  0.981309  1.980756  1.747054 -1.331562
# 17647 -0.376661 -0.259027  0.981309  1.980756  1.747054  1.403260
# 17648 -0.380529 -0.259027  0.981309  1.980756  1.747054  0.605603
# 17649 -0.380424 -0.259027  0.981309  1.980756  1.747054 -0.192053
# 17650 -0.380753 -0.259027  0.981309  1.980756  1.747054 -0.989709
#
# [17651 rows x 13 columns]

# %% [markdown]
# # Applying PCA

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=13)  # Total we have 13 features in the data

data_pca=pca.fit_transform(x_scaled) # Fit the data to PCA
pca_df=pd.DataFrame(data_pca,columns=features)
pca_df
# Out:
#            Date  Total Volume      4046      4225      4770  Total Bags  \
# 0     -0.858039      1.297667  1.588707  1.235542 -1.013972   -0.699622
# 1     -0.868149      1.331625  1.546419  0.440675 -1.013025   -0.666128
# 2     -0.789907      1.385817  1.513961 -0.357032 -1.009470   -0.651002
# 3     -0.845735      1.413496  1.468840 -1.151006 -1.013154   -0.609639
# 4     -0.881841      1.345683  1.596649  1.463697 -1.014495   -0.706073
# ...         ...           ...       ...       ...       ...         ...
# 17646 -1.101576     -2.498915 -1.503933 -1.309331  0.538402    0.929941
# 17647 -1.116824     -2.560724 -1.364121  1.417726  0.534746    0.824682
# 17648 -1.111911     -2.521258 -1.397797  0.622450  0.538336    0.863389
# 17649 -1.105383     -2.484764 -1.439609 -0.172769  0.540611    0.893360
# 17650 -1.105505     -2.450002 -1.486114 -0.967913  0.540848    0.919794
#
#        Small Bags  Large Bags  XLarge Bags      type      year    region  \
# 0        0.528071   -0.319652    -0.060963 -0.048520  0.346379  0.000002
# 1        0.553892   -0.314384    -0.059686 -0.075020  0.349171  0.000002
# 2        0.470421   -0.351138    -0.112576  0.019653  0.352560  0.000003
# 3        0.536174   -0.324861    -0.083672 -0.036330  0.355137  0.000003
# 4        0.550504   -0.308338    -0.053094 -0.054603  0.283320  0.000002
# ...           ...         ...          ...       ...       ...       ...
# 17646   -0.782789    0.213315     0.186690  0.049974 -0.240262 -0.000006
# 17647   -0.815546    0.217613     0.200228  0.094254 -0.314317 -0.000006
# 17648   -0.812127    0.230582     0.200583  0.077998 -0.311239 -0.000006
# 17649   -0.801018    0.227443     0.193770  0.064849 -0.308366 -0.000006
# 17650   -0.783166    0.214769     0.188214  0.055044 -0.305627 -0.000006
#
#                 Day
# 0      5.491369e-09
# 1      5.199819e-09
# 2      4.420533e-09
# 3      4.396696e-09
# 4      5.029082e-09
# ...             ...
# 17646  2.679418e-09
# 17647  3.202420e-09
# 17648  2.866192e-09
# 17649  2.492827e-09
# 17650  2.146384e-09
#
# [17651 rows x 13 columns]

# %% [markdown]
# # Module building

# %%
x_train,x_test,y_train,y_test=train_test_split(pca_df,Y,test_size=0.25,random_state=42)
print(len(x_train),len(x_test),len(y_train),len(y_test))
y_test
# Out:
# 13238 4413 13238 4413
# 3596     1.36
# 7141     1.70
# 4625     1.22
# 5456     0.81
# 10969    1.85
#          ...
# 3618     1.05
# 16950    1.97
# 11096    1.73
# 4588     1.30
# 9061     0.90
# Name: AveragePrice, Length: 4413, dtype: float64

# %% [markdown]
# # Finding Best parameter tunings for the regressor algorithm

# %% [raw]
# Lasso

# %%
alpha_value={'alpha':[1,.1,.01,.001,.0001,0]}
model_test=Lasso()
grid=GridSearchCV(estimator=model_test,param_grid=alpha_value)
grid.fit(x_train,y_train)
print(grid)
print(grid.best_score_)
print(grid.best_estimator_.alpha)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 0.44400920800533206
# 0.0001
# {'alpha': 0.0001}

# %% [markdown]
# # Ridge model

# %%
alpha_value1={'alpha':[1,.1,.01,.001,.0001,0]}
model_test1=Ridge()
grid=GridSearchCV(estimator=model_test1,param_grid=alpha_value)
grid.fit(x_train,y_train)
print(grid)
print(grid.best_score_)
print(grid.best_estimator_.alpha)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 0.4440130067725203
# 0.0001
# {'alpha': 0.0001}

# %% [markdown]
# # Decision Tree Regressor

# %%
Min_Samples={'min_samples_leaf':[100,150,1000,1]}
model_test2=DecisionTreeRegressor()
grid=GridSearchCV(estimator=model_test2,param_grid=Min_Samples)
grid.fit(x_train,y_train)
print(grid)
print(grid.best_score_)
print(grid.best_estimator_.min_samples_leaf)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'min_samples_leaf': [100, 150, 1000, 1]})
# 0.5951355034749058
# 1
# {'min_samples_leaf': 1}

# %% [markdown]
# # Predicting output using models

# %%
model=[Lasso(alpha=0,max_iter=50),Ridge(alpha=0),LinearRegression(),DecisionTreeRegressor(max_depth=15,min_samples_leaf=1),RandomForestRegressor(n_estimators=500,max_depth=6,min_samples_leaf=20,n_jobs=3)]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Model Score = \n',m,'is :')
    print("EV score",explained_variance_score(y_test,predm))
    print("R2_score",r2_score(y_test,predm))
    print("MTD",mean_tweedie_deviance(y_test,predm))
    print("-------------------------------------------")
# Out:
# Model Score =
#  Lasso(alpha=0, max_iter=50) is :
# EV score 0.4334860848820198
# R2_score 0.43309329040192357
# MTD 0.08513831948586774
# -------------------------------------------
# Model Score =
#  Ridge(alpha=0) is :
# EV score 0.4334860848820198
# R2_score 0.43309329040192357
# MTD 0.08513831948586774
# -------------------------------------------
# Model Score =
#  LinearRegression() is :
# EV score 0.4334860848820198
# R2_score 0.43309329040192357
# MTD 0.08513831948586774
# -------------------------------------------
# Model Score =
#  DecisionTreeRegressor(max_depth=15) is :
# EV score 0.6462433026036469
# R2_score 0.6457517379109945
# MTD 0.053201172616972485
# -------------------------------------------
# Model Score =
#  RandomForestRegressor(max_depth=6, min_samples_leaf=20, n_estimators=500,
#                       n_jobs=3) is :
# EV score 0.5988225685666947
# R2_score 0.5983834170969496
# MTD 0.06031496958338065
# -------------------------------------------

# %%
##In the above data RandomForestRegressor giving a best accurate values.

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(RandomForestRegressor(max_depth=6, min_samples_leaf=20, n_estimators=500,n_jobs=3),'Avocado_price.pkl')
# Out:
# ['Avocado_price.pkl']

# %% [markdown]
# # Classification model

# %%
x_clf=df_out.drop(['region','Date'],axis=1)
y_clf=df_out['region']
x_clf
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  Day
# 0         8603.62       93.25          0.0     0  2015   27
# 1         9408.07       97.49          0.0     0  2015   20
# 2         8042.21      103.14          0.0     0  2015   13
# 3         5677.40      133.76          0.0     0  2015    6
# 4         5986.26      197.69          0.0     0  2015   29
# ...           ...         ...          ...   ...   ...  ...
# 18244    13066.82      431.85          0.0     1  2018    4
# 18245     8940.04      324.80          0.0     1  2018   28
# 18246     9351.80       42.31          0.0     1  2018   21
# 18247    10919.54       50.00          0.0     1  2018   14
# 18248    11988.14       26.01          0.0     1  2018    7
#
# [17651 rows x 12 columns]

# %%
##Importng required libraries
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Scaling Data

# %%
sc=StandardScaler()
sc.fit_transform(x_clf)
x_clf=pd.DataFrame(x_clf,columns=x_clf.columns)
x_clf
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  Day
# 0         8603.62       93.25          0.0     0  2015   27
# 1         9408.07       97.49          0.0     0  2015   20
# 2         8042.21      103.14          0.0     0  2015   13
# 3         5677.40      133.76          0.0     0  2015    6
# 4         5986.26      197.69          0.0     0  2015   29
# ...           ...         ...          ...   ...   ...  ...
# 18244    13066.82      431.85          0.0     1  2018    4
# 18245     8940.04      324.80          0.0     1  2018   28
# 18246     9351.80       42.31          0.0     1  2018   21
# 18247    10919.54       50.00          0.0     1  2018   14
# 18248    11988.14       26.01          0.0     1  2018    7
#
# [17651 rows x 12 columns]

# %% [markdown]
# # Buliding model

# %% [markdown]
# ##Finding Best Random State

# %%
models=[DecisionTreeClassifier(),SVC(),KNeighborsClassifier(),RandomForestClassifier()]

max_acc=0
for r_state in range(30,80):
    xc_train,xc_test,yc_train,yc_test=train_test_split(x_clf,y_clf,test_size=0.25,random_state=r_state)
    for model in models:
        model.fit(xc_train,yc_train)
        pred_c=model.predict(xc_test)
        acc_score=accuracy_score(yc_test,pred_c)
        print("Accuracy score is :",acc_score,"At Random State : ",r_state)
        if acc_score>max_acc:
            max_acc=acc_score
            final_state=r_state
            
print("Best Random state ",final_state,"Best accuracy score ",max_acc)
# Out:
# Accuracy score is : 0.7910718332200317 At Random State :  30
# Accuracy score is : 0.24994334919555858 At Random State :  30
# Accuracy score is : 0.6464989802855201 At Random State :  30
# Accuracy score is : 0.8964423294810786 At Random State :  30
# Accuracy score is : 0.7869929753002493 At Random State :  31
# Accuracy score is : 0.26308633582596874 At Random State :  31
# Accuracy score is : 0.6483118060276456 At Random State :  31
# Accuracy score is : 0.9036936324495808 At Random State :  31
# Accuracy score is : 0.7767958305007931 At Random State :  32
# Accuracy score is : 0.24722411058237026 At Random State :  32
# Accuracy score is : 0.649444822116474 At Random State :  32
# Accuracy score is : 0.9039202356673465 At Random State :  32
# Accuracy score is : 0.7912984364377974 At Random State :  33
# Accuracy score is : 0.2519827781554498 At Random State :  33
# Accuracy score is : 0.6675730795377295 At Random State :  33
# Accuracy score is : 0.9048266485384092 At Random State :  33
# Accuracy score is : 0.7910718332200317 At Random State :  34
# Accuracy score is : 0.2660321776569227 At Random State :  34
# Accuracy score is : 0.6492182188987083 At Random State :  34
# Accuracy score is : 0.905733061409472 At Random State :  34
# Accuracy score is : 0.7772490369363245 At Random State :  35
# Accuracy score is : 0.2676184001812826 At Random State :  35
# Accuracy score is : 0.6469521867210515 At Random State :  35
# Accuracy score is : 0.8980285520054385 At Random State :  35
# Accuracy score is : 0.7919782460910945 At Random State :  36
# Accuracy score is : 0.2465443009290732 At Random State :  36
# Accuracy score is : 0.6503512349875368 At Random State :  36
# Accuracy score is : 0.9009743938363924 At Random State :  36
# Accuracy score is : 0.7883525946068434 At Random State :  37
# Accuracy score is : 0.25832766825288916 At Random State :  37
# Accuracy score is : 0.6607749830047587 At Random State :  37
# Accuracy score is : 0.8982551552232042 At Random State :  37
# Accuracy score is : 0.7840471334692952 At Random State :  38
# Accuracy score is : 0.25946068434171765 At Random State :  38
# Accuracy score is : 0.6469521867210515 At Random State :  38
# Accuracy score is : 0.8989349648765013 At Random State :  38
# Accuracy score is : 0.770224337185588 At Random State :  39
# Accuracy score is : 0.2585542714706549 At Random State :  39
# Accuracy score is : 0.6381146612281895 At Random State :  39
# Accuracy score is : 0.8885112168592794 At Random State :  39
# Accuracy score is : 0.782007704509404 At Random State :  40
# Accuracy score is : 0.26172671651937457 At Random State :  40
# Accuracy score is : 0.6444595513256288 At Random State :  40
# Accuracy score is : 0.8975753455699071 At Random State :  40
# Accuracy score is : 0.77906186267845 At Random State :  41
# Accuracy score is : 0.25379560389757533 At Random State :  41
# Accuracy score is : 0.6539768864717879 At Random State :  41
# Accuracy score is : 0.902787219578518 At Random State :  41
# Accuracy score is : 0.7863131656469522 At Random State :  42
# Accuracy score is : 0.2492635395422615 At Random State :  42
# Accuracy score is : 0.6451393609789259 At Random State :  42
# Accuracy score is : 0.8898708361658736 At Random State :  42
# Accuracy score is : 0.7792884658962157 At Random State :  43
# Accuracy score is : 0.256288239292998 At Random State :  43
# Accuracy score is : 0.648765012463177 At Random State :  43
# Accuracy score is : 0.8959891230455472 At Random State :  43
# Accuracy score is : 0.7971901200997055 At Random State :  44
# Accuracy score is : 0.24699750736460457 At Random State :  44
# Accuracy score is : 0.6539768864717879 At Random State :  44
# Accuracy score is : 0.9002945841830954 At Random State :  44
# Accuracy score is : 0.7858599592114208 At Random State :  45
# Accuracy score is : 0.24586449127577611 At Random State :  45
# Accuracy score is : 0.6501246317697711 At Random State :  45
# Accuracy score is : 0.9009743938363924 At Random State :  45
# Accuracy score is : 0.7903920235667347 At Random State :  46
# Accuracy score is : 0.25447541355087244 At Random State :  46
# Accuracy score is : 0.6551099025606164 At Random State :  46
# Accuracy score is : 0.9016542034896895 At Random State :  46
# Accuracy score is : 0.7799682755495128 At Random State :  47
# Accuracy score is : 0.2585542714706549 At Random State :  47
# Accuracy score is : 0.6508044414230683 At Random State :  47
# Accuracy score is : 0.8923634715612961 At Random State :  47
# Accuracy score is : 0.7829141173804668 At Random State :  48
# Accuracy score is : 0.2662587808746884 At Random State :  48
# Accuracy score is : 0.651710854294131 At Random State :  48
# Accuracy score is : 0.9046000453206435 At Random State :  48
# Accuracy score is : 0.799682755495128 At Random State :  49
# Accuracy score is : 0.26172671651937457 At Random State :  49
# Accuracy score is : 0.6591887604803989 At Random State :  49
# Accuracy score is : 0.9012009970541581 At Random State :  49
# Accuracy score is : 0.790845230002266 At Random State :  50
# Accuracy score is : 0.26195331973714026 At Random State :  50
# Accuracy score is : 0.6566961250849762 At Random State :  50
# Accuracy score is : 0.9102651257647859 At Random State :  50
# Accuracy score is : 0.782007704509404 At Random State :  51
# Accuracy score is : 0.2429186494448221 At Random State :  51
# Accuracy score is : 0.6535236800362565 At Random State :  51
# Accuracy score is : 0.9023340131429867 At Random State :  51
# Accuracy score is : 0.7940176750509857 At Random State :  52
# Accuracy score is : 0.2433718558803535 At Random State :  52
# Accuracy score is : 0.6557897122139135 At Random State :  52
# Accuracy score is : 0.9077724903693632 At Random State :  52
# Accuracy score is : 0.7953772943575799 At Random State :  53
# Accuracy score is : 0.2556084296397009 At Random State :  53
# Accuracy score is : 0.6403806934058464 At Random State :  53
# Accuracy score is : 0.8993881713120326 At Random State :  53
# Accuracy score is : 0.7817811012916384 At Random State :  54
# Accuracy score is : 0.2587808746884206 At Random State :  54
# Accuracy score is : 0.6508044414230683 At Random State :  54
# Accuracy score is : 0.8980285520054385 At Random State :  54
# Accuracy score is : 0.781327894856107 At Random State :  55
# Accuracy score is : 0.259913890777249 At Random State :  55
# Accuracy score is : 0.6424201223657376 At Random State :  55
# Accuracy score is : 0.8964423294810786 At Random State :  55
# Accuracy score is : 0.7822343077271697 At Random State :  56
# Accuracy score is : 0.2585542714706549 At Random State :  56
# Accuracy score is : 0.6467255835032858 At Random State :  56
# Accuracy score is : 0.902107409925221 At Random State :  56
# Accuracy score is : 0.7856333559936551 At Random State :  57
# Accuracy score is : 0.25379560389757533 At Random State :  57
# Accuracy score is : 0.6469521867210515 At Random State :  57
# Accuracy score is : 0.8912304554724677 At Random State :  57
# Accuracy score is : 0.7919782460910945 At Random State :  58
# Accuracy score is : 0.26240652617267163 At Random State :  58
# Accuracy score is : 0.6571493315205076 At Random State :  58
# Accuracy score is : 0.9012009970541581 At Random State :  58
# Accuracy score is : 0.7888058010423749 At Random State :  59
# Accuracy score is : 0.2639927486970315 At Random State :  59
# Accuracy score is : 0.6587355540448674 At Random State :  59
# Accuracy score is : 0.8953093133922502 At Random State :  59
# Accuracy score is : 0.7840471334692952 At Random State :  60
# Accuracy score is : 0.2601404939950147 At Random State :  60
# Accuracy score is : 0.6390210740992522 At Random State :  60
# Accuracy score is : 0.902107409925221 At Random State :  60
# Accuracy score is : 0.790845230002266 At Random State :  61
# Accuracy score is : 0.2664853840924541 At Random State :  61
# Accuracy score is : 0.6383412644459552 At Random State :  61
# Accuracy score is : 0.8980285520054385 At Random State :  61
# Accuracy score is : 0.7838205302515295 At Random State :  62
# Accuracy score is : 0.25719465216406073 At Random State :  62
# Accuracy score is : 0.6449127577611602 At Random State :  62
# Accuracy score is : 0.899841377747564 At Random State :  62
# Accuracy score is : 0.790165420348969 At Random State :  63
# Accuracy score is : 0.25379560389757533 At Random State :  63
# Accuracy score is : 0.6435531384545661 At Random State :  63
# Accuracy score is : 0.8973487423521413 At Random State :  63
# Accuracy score is : 0.7897122139134376 At Random State :  64
# Accuracy score is : 0.2497167459777929 At Random State :  64
# Accuracy score is : 0.6555631089961478 At Random State :  64
# Accuracy score is : 0.8957625198277815 At Random State :  64
# Accuracy score is : 0.7869929753002493 At Random State :  65
# Accuracy score is : 0.2635395422615001 At Random State :  65
# Accuracy score is : 0.6589621572626331 At Random State :  65
# Accuracy score is : 0.9000679809653297 At Random State :  65
# Accuracy score is : 0.7856333559936551 At Random State :  66
# Accuracy score is : 0.26920462270564244 At Random State :  66
# Accuracy score is : 0.6451393609789259 At Random State :  66
# Accuracy score is : 0.9032404260140494 At Random State :  66
# Accuracy score is : 0.77906186267845 At Random State :  67
# Accuracy score is : 0.26444595513256286 At Random State :  67
# Accuracy score is : 0.6537502832540222 At Random State :  67
# Accuracy score is : 0.8937230908678904 At Random State :  67
# Accuracy score is : 0.7856333559936551 At Random State :  68
# Accuracy score is : 0.24495807840471334 At Random State :  68
# Accuracy score is : 0.6381146612281895 At Random State :  68
# Accuracy score is : 0.8971221391343757 At Random State :  68
# Accuracy score is : 0.7946974847042828 At Random State :  69
# Accuracy score is : 0.2608203036483118 At Random State :  69
# Accuracy score is : 0.6503512349875368 At Random State :  69
# Accuracy score is : 0.9089055064581917 At Random State :  69
# Accuracy score is : 0.7804214819850442 At Random State :  70
# Accuracy score is : 0.25583503285746656 At Random State :  70
# Accuracy score is : 0.6489916156809427 At Random State :  70
# Accuracy score is : 0.8989349648765013 At Random State :  70
# Accuracy score is : 0.7801948787672784 At Random State :  71
# Accuracy score is : 0.26263312939043737 At Random State :  71
# Accuracy score is : 0.6498980285520054 At Random State :  71
# Accuracy score is : 0.8989349648765013 At Random State :  71
# Accuracy score is : 0.7928846589621572 At Random State :  72
# Accuracy score is : 0.2728302741898935 At Random State :  72
# Accuracy score is : 0.6573759347382733 At Random State :  72
# Accuracy score is : 0.9048266485384092 At Random State :  72
# Accuracy score is : 0.7845003399048266 At Random State :  73
# Accuracy score is : 0.2648991615680943 At Random State :  73
# Accuracy score is : 0.6535236800362565 At Random State :  73
# Accuracy score is : 0.9034670292318151 At Random State :  73
# Accuracy score is : 0.7910718332200317 At Random State :  74
# Accuracy score is : 0.2517561749376841 At Random State :  74
# Accuracy score is : 0.6496714253342397 At Random State :  74
# Accuracy score is : 0.8962157262633129 At Random State :  74
# Accuracy score is : 0.7903920235667347 At Random State :  75
# Accuracy score is : 0.2587808746884206 At Random State :  75
# Accuracy score is : 0.6526172671651937 At Random State :  75
# Accuracy score is : 0.9030138227962837 At Random State :  75
# Accuracy score is : 0.7763426240652618 At Random State :  76
# Accuracy score is : 0.25674144572852936 At Random State :  76
# Accuracy score is : 0.6641740312712441 At Random State :  76
# Accuracy score is : 0.899161568094267 At Random State :  76
# Accuracy score is : 0.7903920235667347 At Random State :  77
# Accuracy score is : 0.24722411058237026 At Random State :  77
# Accuracy score is : 0.651031044640834 At Random State :  77
# Accuracy score is : 0.899841377747564 At Random State :  77
# Accuracy score is : 0.7835939270337638 At Random State :  78
# Accuracy score is : 0.26308633582596874 At Random State :  78
# Accuracy score is : 0.6442329481078631 At Random State :  78
# Accuracy score is : 0.9009743938363924 At Random State :  78
# Accuracy score is : 0.7865397688647179 At Random State :  79
# Accuracy score is : 0.2662587808746884 At Random State :  79
# Accuracy score is : 0.6603217765692273 At Random State :  79
# Accuracy score is : 0.9050532517561749 At Random State :  79
# Best Random state  50 Best accuracy score  0.9102651257647859

# %%
print("Best Random state ",final_state,"Best accuracy score ",max_acc)
# Out:
# Best Random state  50 Best accuracy score  0.9102651257647859

# %% [markdown]
# # Modeling using Models

# %%
from sklearn.metrics import confusion_matrix,classification_report
x_train,x_test,y_train,y_test=train_test_split(x_clf,y_clf,test_size=0.30,random_state=66)
models=[LogisticRegression(),KNeighborsClassifier(),DecisionTreeClassifier(),RandomForestClassifier()]
for model in models:
    model.fit(xc_train,yc_train)
    predlr=model.predict(xc_test)
    print("Model Name",model)
    print("Accuracy",accuracy_score(yc_test,predlr)*100)
    print(confusion_matrix(yc_test,predlr))
    print(classification_report(yc_test,predlr))
    print('------------------------------------')
# Out:
# Model Name LogisticRegression()
# Accuracy 16.67799682755495
# [[ 0  0  1 ...  0  0  0]
#  [ 0  5  0 ...  4  1  2]
#  [ 0  0 46 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 27  9  0]
#  [ 0  0  0 ... 12 27  0]
#  [ 1  0  1 ...  4  8  2]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        94
#            1       0.10      0.08      0.09        63
#            2       0.40      0.44      0.42       105
#            3       0.00      0.00      0.00        80
#            4       0.22      0.09      0.13        86
#            5       0.12      0.26      0.17        92
#            6       0.09      0.27      0.14        64
#            7       0.09      0.01      0.02        79
#            8       0.82      0.48      0.61        83
#            9       0.13      0.54      0.21        84
#           10       0.00      0.00      0.00        80
#           11       0.00      0.00      0.00        84
#           12       0.24      0.49      0.32        90
#           13       0.56      0.35      0.43        85
#           14       0.00      0.00      0.00        83
#           15       0.11      0.28      0.15        60
#           16       0.00      0.00      0.00        67
#           17       0.00      0.00      0.00        86
#           18       0.09      0.06      0.07        97
#           19       0.60      0.04      0.08        73
#           20       0.00      0.00      0.00        74
#           21       0.27      0.05      0.08        81
#           22       0.18      0.35      0.24        92
#           23       0.00      0.00      0.00        82
#           24       0.13      0.07      0.09        88
#           25       0.15      0.42      0.22        77
#           26       0.20      0.06      0.09        87
#           27       0.27      0.26      0.26        93
#           28       0.11      0.20      0.14        83
#           29       0.16      0.76      0.26        95
#           30       0.09      0.23      0.13        81
#           31       0.00      0.00      0.00        78
#           32       0.16      0.12      0.14        83
#           33       0.23      0.30      0.26        74
#           34       0.00      0.00      0.00        85
#           35       0.27      0.32      0.29        72
#           36       0.13      0.05      0.07        79
#           37       0.00      0.00      0.00        79
#           38       0.00      0.00      0.00        96
#           39       0.00      0.00      0.00        80
#           40       0.48      0.17      0.25        90
#           41       0.33      0.02      0.05        82
#           42       0.28      0.60      0.38        82
#           43       0.07      0.01      0.02        83
#           44       0.00      0.00      0.00        92
#           45       0.16      0.23      0.19        78
#           46       0.15      0.33      0.20        88
#           47       0.00      0.00      0.00        76
#           48       0.03      0.12      0.05        84
#           49       0.00      0.00      0.00        80
#           50       0.00      0.00      0.00        85
#           51       0.14      0.60      0.23        45
#           52       0.19      0.37      0.25        73
#           53       0.08      0.02      0.04        81
#
#     accuracy                           0.17      4413
#    macro avg       0.14      0.17      0.13      4413
# weighted avg       0.15      0.17      0.13      4413
#
# ------------------------------------
# Model Name KNeighborsClassifier()
# Accuracy 66.03217765692273
# [[72  0  0 ...  0  0  0]
#  [ 0 40  1 ...  0  0  0]
#  [ 0  0 82 ...  0  0  2]
#  ...
#  [ 0  0  0 ... 40  0  0]
#  [ 0  0  0 ...  0 58  0]
#  [ 0  3  0 ...  0  0 39]]
#               precision    recall  f1-score   support
#
#            0       0.58      0.77      0.66        94
#            1       0.52      0.63      0.57        63
#            2       0.82      0.78      0.80       105
#            3       0.65      0.75      0.69        80
#            4       0.68      0.83      0.75        86
#            5       0.48      0.46      0.47        92
#            6       0.73      0.75      0.74        64
#            7       0.64      0.80      0.71        79
#            8       0.89      0.93      0.91        83
#            9       0.60      0.61      0.60        84
#           10       0.47      0.64      0.54        80
#           11       0.61      0.80      0.69        84
#           12       0.77      0.63      0.70        90
#           13       0.54      0.62      0.58        85
#           14       0.72      0.77      0.74        83
#           15       0.65      0.67      0.66        60
#           16       0.55      0.61      0.58        67
#           17       0.56      0.51      0.54        86
#           18       0.69      0.54      0.60        97
#           19       0.52      0.63      0.57        73
#           20       0.70      0.72      0.71        74
#           21       0.60      0.69      0.64        81
#           22       0.77      0.82      0.79        92
#           23       0.61      0.59      0.60        82
#           24       0.42      0.43      0.43        88
#           25       0.78      0.75      0.77        77
#           26       0.47      0.47      0.47        87
#           27       0.73      0.74      0.74        93
#           28       0.72      0.70      0.71        83
#           29       0.88      0.81      0.84        95
#           30       0.62      0.56      0.58        81
#           31       0.58      0.60      0.59        78
#           32       0.69      0.65      0.67        83
#           33       0.71      0.74      0.72        74
#           34       0.69      0.64      0.66        85
#           35       0.68      0.88      0.77        72
#           36       0.49      0.57      0.53        79
#           37       0.54      0.44      0.49        79
#           38       0.54      0.41      0.46        96
#           39       0.62      0.60      0.61        80
#           40       0.76      0.77      0.76        90
#           41       0.71      0.74      0.73        82
#           42       0.86      0.91      0.89        82
#           43       0.63      0.49      0.55        83
#           44       0.60      0.57      0.58        92
#           45       0.91      0.86      0.88        78
#           46       0.90      0.86      0.88        88
#           47       0.76      0.55      0.64        76
#           48       0.72      0.49      0.58        84
#           49       0.63      0.61      0.62        80
#           50       0.43      0.29      0.35        85
#           51       0.82      0.89      0.85        45
#           52       0.92      0.79      0.85        73
#           53       0.76      0.48      0.59        81
#
#     accuracy                           0.66      4413
#    macro avg       0.66      0.66      0.66      4413
# weighted avg       0.66      0.66      0.66      4413
#
# ------------------------------------
# Model Name DecisionTreeClassifier()
# Accuracy 78.74461817357806
# [[76  0  0 ...  0  0  0]
#  [ 0 47  0 ...  0  0  1]
#  [ 0  0 93 ...  0  0  3]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  0 64  0]
#  [ 0  1  0 ...  0  0 47]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82        94
#            1       0.58      0.75      0.65        63
#            2       0.91      0.89      0.90       105
#            3       0.79      0.78      0.78        80
#            4       0.82      0.86      0.84        86
#            5       0.68      0.77      0.72        92
#            6       0.95      0.91      0.93        64
#            7       0.81      0.78      0.79        79
#            8       0.93      0.92      0.92        83
#            9       0.81      0.64      0.72        84
#           10       0.68      0.69      0.68        80
#           11       0.81      0.92      0.86        84
#           12       0.83      0.79      0.81        90
#           13       0.72      0.72      0.72        85
#           14       0.77      0.82      0.80        83
#           15       0.84      0.93      0.88        60
#           16       0.84      0.87      0.85        67
#           17       0.84      0.71      0.77        86
#           18       0.93      0.79      0.86        97
#           19       0.79      0.67      0.73        73
#           20       0.82      0.81      0.82        74
#           21       0.62      0.58      0.60        81
#           22       0.93      0.92      0.93        92
#           23       0.80      0.74      0.77        82
#           24       0.61      0.55      0.57        88
#           25       0.93      0.91      0.92        77
#           26       0.64      0.67      0.66        87
#           27       0.82      0.80      0.81        93
#           28       0.84      0.86      0.85        83
#           29       0.91      0.88      0.90        95
#           30       0.82      0.89      0.85        81
#           31       0.66      0.67      0.66        78
#           32       0.73      0.81      0.77        83
#           33       0.76      0.84      0.79        74
#           34       0.75      0.86      0.80        85
#           35       0.79      0.90      0.84        72
#           36       0.64      0.62      0.63        79
#           37       0.71      0.75      0.73        79
#           38       0.80      0.74      0.77        96
#           39       0.76      0.81      0.79        80
#           40       0.86      0.80      0.83        90
#           41       0.75      0.90      0.82        82
#           42       0.85      0.90      0.88        82
#           43       0.80      0.71      0.75        83
#           44       0.72      0.85      0.78        92
#           45       0.95      0.97      0.96        78
#           46       0.91      0.88      0.89        88
#           47       0.68      0.79      0.73        76
#           48       0.78      0.62      0.69        84
#           49       0.78      0.71      0.75        80
#           50       0.48      0.48      0.48        85
#           51       1.00      1.00      1.00        45
#           52       0.96      0.88      0.91        73
#           53       0.72      0.58      0.64        81
#
#     accuracy                           0.79      4413
#    macro avg       0.79      0.79      0.79      4413
# weighted avg       0.79      0.79      0.79      4413
#
# ------------------------------------
# Model Name RandomForestClassifier()
# Accuracy 90.2787219578518
# [[ 87   0   0 ...   0   0   0]
#  [  0  57   0 ...   0   0   0]
#  [  0   0 102 ...   0   0   0]
#  ...
#  [  0   0   0 ...  45   0   0]
#  [  0   0   0 ...   0  72   0]
#  [  0   0   0 ...   0   0  57]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        94
#            1       0.80      0.90      0.85        63
#            2       0.98      0.97      0.98       105
#            3       0.92      0.82      0.87        80
#            4       0.93      0.94      0.94        86
#            5       0.93      0.82      0.87        92
#            6       1.00      0.98      0.99        64
#            7       0.91      0.87      0.89        79
#            8       0.99      0.96      0.98        83
#            9       0.93      0.80      0.86        84
#           10       0.87      0.91      0.89        80
#           11       0.90      0.98      0.94        84
#           12       0.91      0.97      0.94        90
#           13       0.83      0.85      0.84        85
#           14       0.89      0.89      0.89        83
#           15       1.00      0.97      0.98        60
#           16       0.97      0.91      0.94        67
#           17       0.95      0.92      0.93        86
#           18       0.95      0.91      0.93        97
#           19       0.85      0.88      0.86        73
#           20       0.99      0.95      0.97        74
#           21       0.83      0.83      0.83        81
#           22       0.98      0.99      0.98        92
#           23       0.83      0.89      0.86        82
#           24       0.69      0.66      0.67        88
#           25       0.96      1.00      0.98        77
#           26       0.95      0.79      0.86        87
#           27       0.89      0.91      0.90        93
#           28       0.99      0.98      0.98        83
#           29       1.00      0.97      0.98        95
#           30       0.95      1.00      0.98        81
#           31       0.76      0.78      0.77        78
#           32       0.84      0.94      0.89        83
#           33       0.83      0.91      0.86        74
#           34       0.95      0.95      0.95        85
#           35       0.93      0.94      0.94        72
#           36       0.73      0.77      0.75        79
#           37       0.87      0.92      0.90        79
#           38       0.90      0.94      0.92        96
#           39       0.93      0.95      0.94        80
#           40       0.91      0.87      0.89        90
#           41       0.90      0.95      0.92        82
#           42       0.89      1.00      0.94        82
#           43       0.92      0.84      0.88        83
#           44       0.92      0.93      0.93        92
#           45       1.00      1.00      1.00        78
#           46       0.96      0.99      0.97        88
#           47       0.91      0.89      0.90        76
#           48       0.95      0.82      0.88        84
#           49       0.84      0.96      0.90        80
#           50       0.60      0.62      0.61        85
#           51       1.00      1.00      1.00        45
#           52       0.99      0.99      0.99        73
#           53       0.97      0.70      0.81        81
#
#     accuracy                           0.90      4413
#    macro avg       0.91      0.90      0.90      4413
# weighted avg       0.90      0.90      0.90      4413
#
# ------------------------------------

# %% [markdown]
# ##Hence RandomForestClassifier has a best accuracy score of 90%,so this model is best fit.

# %% [markdown]
# # Cross Validation score

# %%
from sklearn.model_selection import cross_val_score
models=[LogisticRegression(),KNeighborsClassifier(),DecisionTreeClassifier(),RandomForestClassifier()]
for model in models:
    scr=cross_val_score(model,x_clf,y_clf,cv=5)
    print("Model Name :",model)
    print("Cross validation score is: ", scr.mean()*100)
    print('---------------------------------------')
# Out:
# Model Name : LogisticRegression()
# Cross validation score is:  13.738292083954098
# ---------------------------------------
# Model Name : KNeighborsClassifier()
# Cross validation score is:  43.294876701140765
# ---------------------------------------
# Model Name : DecisionTreeClassifier()
# Cross validation score is:  55.00587832736835
# ---------------------------------------
# Model Name : RandomForestClassifier()
# Cross validation score is:  67.18066530118104
# ---------------------------------------

# %% [markdown]
# Hence for region prdiction the RandomForestClassifier model is best giving accuracy score of 90%,cross validation score is 67%

# %% [markdown]
# # Save Model

# %%
joblib.dump(RandomForestRegressor,'Avocado_region.pkl')
# Out:
# ['Avocado_region.pkl']
